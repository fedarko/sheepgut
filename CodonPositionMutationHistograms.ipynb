# %% [markdown]
# # Codon position (CP) mutation histograms

# %%
# %run "Header.ipynb"
# %run "LoadMutationJSONData.ipynb"

# %%
# %run "GeneUtils.ipynb"

# %% [markdown]
# ## Values of _min-freq_ to consider: 2%, 1%, 0.5%, 0.25%, 0.1%, 0.05%, 0%

# %%
percentages = [2, 1, 0.5, 0.25, 0.1, 0.05, 0]

# %% [markdown]
# ### Without normalization (so the y-axis is just # of mutated positions)

# %%
histogram_matrix_maker(percentages, figfilename="unnormalized-cp-hists.png")
# Out:
# CAMP: min-freq = 2% [102, 73, 256, 18]
# BACTERIA: min-freq = 2% [3592, 2337, 13701, 2966]
# BACTEROIDALES: min-freq = 2% [62, 59, 130, 88]
# CAMP: min-freq = 1% [110, 84, 262, 37]
# BACTERIA: min-freq = 1% [4402, 2924, 16276, 3535]
# BACTEROIDALES: min-freq = 1% [128, 108, 204, 218]
# CAMP: min-freq = 0.5% [199, 163, 396, 98]
# BACTERIA: min-freq = 0.5% [4834, 3261, 17264, 3975]
# BACTEROIDALES: min-freq = 0.5% [556, 439, 749, 631]
# CAMP: min-freq = 0.25% [680, 630, 926, 499]
# BACTERIA: min-freq = 0.25% [7188, 5550, 20859, 5855]
# BACTEROIDALES: min-freq = 0.25% [2235, 1956, 2788, 2746]
# CAMP: min-freq = 0.1% [10142, 10413, 11989, 5062]
# BACTERIA: min-freq = 0.1% [41449, 41876, 59652, 20527]
# BACTEROIDALES: min-freq = 0.1% [28148, 27681, 29327, 28456]
# CAMP: min-freq = 0.05% [54356, 58730, 60789, 19749]
# BACTERIA: min-freq = 0.05% [179944, 184002, 202621, 67636]
# BACTEROIDALES: min-freq = 0.05% [114883, 116876, 115701, 95413]
# CAMP: min-freq = 0% [213381, 222105, 223807, 63216]
# BACTERIA: min-freq = 0% [179944, 184002, 202621, 67636]
# BACTEROIDALES: min-freq = 0% [336819, 345003, 335877, 245797]

# %% [markdown]
# ### With normalization, and making y-axes comparable for each row

# %%
histogram_matrix_maker(percentages, normalize=True, make_yaxes_comparable=True,
                       figfilename="normalized-cp-hists.png")
# Out:
# CAMP: min-freq = 2% [0.00025659538178625607, 0.00018364179284702638, 0.0006440040954635446, 0.0001785607999523838]
# BACTERIA: min-freq = 2% [0.005532852854148023, 0.0035997430735367282, 0.021104013628809034, 0.01428860476543757]
# BACTEROIDALES: min-freq = 2% [8.076997232977077e-05, 7.686174786220121e-05, 0.00016935639359468065, 0.00017127553562531141]
# CAMP: min-freq = 1% [0.0002767205097694918, 0.00021131384382397557, 0.0006590979414509714, 0.0003670416443465667]
# BACTERIA: min-freq = 1% [0.006780517334064475, 0.004503914739846552, 0.025070354413728624, 0.0170297430363526]
# BACTEROIDALES: min-freq = 1% [0.00016675091061630094, 0.0001406960808325039, 0.0002657592637947296, 0.00042429621325361236]
# CAMP: min-freq = 0.5% [0.0005006125585829898, 0.0004100494826584288, 0.0009961938351701705, 0.0009721643552963118]
# BACTERIA: min-freq = 0.5% [0.007445938390019917, 0.005023004776552533, 0.02659219701392301, 0.01914942816676141]
# BACTEROIDALES: min-freq = 0.5% [0.0007243242679895572, 0.0005719035137543446, 0.0009757533754031985, 0.001228123442949676]
# CAMP: min-freq = 0.25% [0.0017106358785750403, 0.0015848538286798168, 0.00232948356405954, 0.004950102176457751]
# BACTERIA: min-freq = 0.25% [0.011071867014369706, 0.008548812177205324, 0.03212967084762628, 0.0282062646330536]
# BACTEROIDALES: min-freq = 0.25% [0.0029116272283393175, 0.0025481623528553488, 0.003632043271861305, 0.005344575236671649]
# CAMP: min-freq = 0.1% [0.025513631000747144, 0.026195369711179257, 0.030160019923876704, 0.05021526496438704]
# BACTERIA: min-freq = 0.1% [0.06384499386179883, 0.06450271328516219, 0.09188355747651387, 0.09888812879977647]
# BACTEROIDALES: min-freq = 0.1% [0.036669567437715926, 0.036061187162264266, 0.03820549965347076, 0.055384280019930246]
# CAMP: min-freq = 0.05% [0.13674018208209543, 0.14774359580692958, 0.15292330062161488, 0.1959109576810904]
# BACTERIA: min-freq = 0.05% [0.277172515029736, 0.2834231600414656, 0.3121024994878414, 0.3258341442734779]
# BACTEROIDALES: min-freq = 0.05% [0.14966285050259767, 0.15225921429055303, 0.15072849304075497, 0.18570355318883908]
# CAMP: min-freq = 0% [0.5367899917738539, 0.5587364438395725, 0.563018064818006, 0.6271055294327719]
# BACTERIA: min-freq = 0% [0.277172515029736, 0.2834231600414656, 0.3121024994878414, 0.3258341442734779]
# BACTEROIDALES: min-freq = 0% [0.4387880856474365, 0.4494497219949662, 0.43756090316461965, 0.4783978730692576]
