# %% [markdown]
# # Codon position (CP) mutation histograms

# %%
# %run "Header.ipynb"
# %run "LoadMutationJSONData.ipynb"

# %%
# %run "GeneUtils.ipynb"

# %% [markdown]
# ## Values of _min-freq_ to consider: 2%, 1%, 0.5%, 0.25%, 0.1%, 0.05%, 0%

# %%
percentages = [2, 1, 0.5, 0.25, 0.1, 0.05, 0]

# %% [markdown]
# ### Without normalization (so the y-axis is just # of mutated positions)

# %%
histogram_matrix_maker(percentages, figfilename="unnormalized-cp-hists.png")
# Out:
# CAMP: min-freq = 2% [102, 73, 256, 18]
# BUT: min-freq = 2% [286, 186, 815, 126]
# BACT: min-freq = 2% [62, 59, 130, 88]
# CAMP: min-freq = 1% [110, 84, 262, 37]
# BUT: min-freq = 1% [320, 227, 861, 169]
# BACT: min-freq = 1% [128, 108, 204, 218]
# CAMP: min-freq = 0.5% [199, 163, 396, 98]
# BUT: min-freq = 0.5% [673, 606, 1325, 486]
# BACT: min-freq = 0.5% [556, 439, 749, 631]
# CAMP: min-freq = 0.25% [680, 630, 926, 499]
# BUT: min-freq = 0.25% [5254, 5464, 6212, 2971]
# BACT: min-freq = 0.25% [2235, 1956, 2788, 2746]
# CAMP: min-freq = 0.1% [10142, 10413, 11989, 5062]
# BUT: min-freq = 0.1% [21447, 22308, 24596, 9426]
# BACT: min-freq = 0.1% [28148, 27681, 29327, 28456]
# CAMP: min-freq = 0.05% [54356, 58730, 60789, 19749]
# BUT: min-freq = 0.05% [58646, 61718, 64865, 21510]
# BACT: min-freq = 0.05% [114883, 116876, 115701, 95413]
# CAMP: min-freq = 0% [213381, 222105, 223807, 63216]
# BUT: min-freq = 0% [171084, 177240, 180300, 53813]
# BACT: min-freq = 0% [336819, 345003, 335877, 245797]

# %% [markdown]
# ### With normalization, and making y-axes comparable for each row

# %%
histogram_matrix_maker(percentages, normalize=True, make_yaxes_comparable=True,
                       figfilename="normalized-cp-hists.png")
# Out:
# CAMP: min-freq = 2% [0.00025659538178625607, 0.00018364179284702638, 0.0006440040954635446, 0.0001785607999523838]
# BUT: min-freq = 2% [0.0005779692665852929, 0.0003758821104365891, 0.001647010322611936, 0.0008145270248430742]
# BACT: min-freq = 2% [8.076997232977077e-05, 7.686174786220121e-05, 0.00016935639359468065, 0.00017127553562531141]
# CAMP: min-freq = 1% [0.0002767205097694918, 0.00021131384382397557, 0.0006590979414509714, 0.0003670416443465667]
# BUT: min-freq = 1% [0.0006466788996758522, 0.00045873784445755767, 0.0017399704144403399, 0.0010925005333212662]
# BACT: min-freq = 1% [0.00016675091061630094, 0.0001406960808325039, 0.0002657592637947296, 0.00042429621325361236]
# CAMP: min-freq = 0.5% [0.0005006125585829898, 0.0004100494826584288, 0.0009961938351701705, 0.0009721643552963118]
# BUT: min-freq = 0.5% [0.0013600465608807767, 0.001224648166261145, 0.0026776548189703254, 0.0031417470958232862]
# BACT: min-freq = 0.5% [0.0007243242679895572, 0.0005719035137543446, 0.0009757533754031985, 0.001228123442949676]
# CAMP: min-freq = 0.25% [0.0017106358785750403, 0.0015848538286798168, 0.00232948356405954, 0.004950102176457751]
# BUT: min-freq = 0.25% [0.010617659184052898, 0.011042042211965176, 0.01255365413995748, 0.019206030085783917]
# BACT: min-freq = 0.25% [0.0029116272283393175, 0.0025481623528553488, 0.003632043271861305, 0.005344575236671649]
# CAMP: min-freq = 0.1% [0.025513631000747144, 0.026195369711179257, 0.030160019923876704, 0.05021526496438704]
# BUT: min-freq = 0.1% [0.04334163237921251, 0.04508160279365284, 0.04970535692633519, 0.060934378858498554]
# BACT: min-freq = 0.1% [0.036669567437715926, 0.036061187162264266, 0.03820549965347076, 0.055384280019930246]
# CAMP: min-freq = 0.05% [0.13674018208209543, 0.14774359580692958, 0.15292330062161488, 0.1959109576810904]
# BUT: min-freq = 0.05% [0.11851603359496884, 0.12472415103185702, 0.13108383383585673, 0.13905139924106769]
# BACT: min-freq = 0.05% [0.14966285050259767, 0.15225921429055303, 0.15072849304075497, 0.18570355318883908]
# CAMP: min-freq = 0% [0.5367899917738539, 0.5587364438395725, 0.563018064818006, 0.6271055294327719]
# BUT: min-freq = 0% [0.34573879022544846, 0.35817927555796264, 0.36436314253611296, 0.34787414911016157]
# BACT: min-freq = 0% [0.4387880856474365, 0.4494497219949662, 0.43756090316461965, 0.4783978730692576]
