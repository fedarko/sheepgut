# %% [markdown]
# # Generate the data for "mutation matrices"
#
# Both for codons (e.g. ATG, TGC) and amino acids (e.g. M, C).
#
# **NOTE 1:** Because this boils down to calling [`AlignedSegment.get_aligned_pairs()`](https://pysam.readthedocs.io/en/latest/api.html#pysam.AlignedSegment.get_aligned_pairs) once for every linear alignment to the selected MAGs, **the first part of this notebook is currently pretty slow**! I've optimized things to the point where this notebook takes around 20 hours on our cluster.
#
# If necessary / desired it should be possible to speed this up even more, using stuff like parallelization / writing this in a faster language like C / etc. There may also be methods in pysam I've overlooked that will help do this faster (from what I can tell the only way to do this in pysam involves calling `get_aligned_pairs()`, but maybe I've missed something...)
#
# **NOTE 2:** This doesn't actually generate the figures for the matrices -- it just outputs JSON files to a folder named `matrix-jsons/`, and another notebook will generate the figures based on these JSON files. This is intended to make it easier to regenerate the figures using different styles / etc. without having to wait hours for this stuff to finish.
#
# **NOTE 3:** We're redoing things so that the overall matrices are only based on individual MAGs -- so it should be possible to either parallelize this on the level of each MAGs (could probably parallelize things even further), or just only run this for individual MAGs. HOWEVER: for now, I'm going to keep generating this data for all of the three selected MAGs, because (i) we need this data for the Syn/NonSyn and Non-nonsense / Nonsense barplots, and (ii) I don't really want to rewrite this entire notebook since this is currently a one-off analysis...

# %%
# %run "Header.ipynb"
# %run "GeneUtils.ipynb"

# %%
import copy
import time
import json
import pysam
import skbio
import pileup
from collections import defaultdict, Counter
from statistics import mean
from parse_sco import parse_sco

# %%
# This is a list of all 64 DNA 3-mers (codons). There's probably a fancier way of generating this than what
# we do here, but this is fine.
codons = []

# We figure out the reverse complements of each of the 64 3-mers in advance -- this avoids
# us having to call str(skbio.DNA(c).reverse_complement()) every time we see a codon, and saves a tiny
# amount of time per alignment (the skbio approach took ~9e-5 seconds every time; the new approach takes ~9e-7
# seconds every time). Considering we're going through well over a million alignments, this actually should save
# us maybe a minute or two. Not much, but it's something. Actually is the time I'm spending documenting this to
# make this code readable less than the amount of time we save here? Hmmm.
codon2revcomp = {}
nts = "ACGT"
for i in nts:
    for j in nts:
        for k in nts:
            c = "{}{}{}".format(i, j, k)
            codons.append(c)
            codon2revcomp[c] = str(skbio.DNA(c).reverse_complement())

# %% [markdown]
# ## Go through all alignments to each genome and figure out which genes they intersect and which codons in these genes they fully cover
#
# __This is the main bottleneck of this notebook__, at least as of writing.
#
# Define a dict which we'll use to keep track of aligned codon frequencies for each codon, for each gene, for each genome.
#
# - For each alignment, see which predicted genes (if any) this alignment intersects within the genome. Note that "intersects" doesn't mean "fully covers".
#
# - For each of these genes, see which codons (if any) this alignment fully covers within the gene.
#
# - Increment aligned codon frequencies for all codons accordingly.
#
# The reason we do things this way, as opposed to iterating over just the alignments overlapping each codon in each gene, is that doing things that way is really slow! I'm pretty sure it's because "find out which alignments overlap this region" is a pretty slow operation when working with large datasets -- and also since these are long reads, doing this on the level of each codon means we're effectively doing a lot of redundant work (you can imagine that, for a given codon, the odds are pretty good that most alignments overlapping it will also overlap adjacent codon(s)).
#
# **Note that we purposefully say "alignment" instead of "read"** since a single read can correspond to multiple distinct linear alignments (e.g. if this read is aligned to both the start and end of a genome, due to a chimeric / supplementary alignment). We assume that no two linear alignments from a read cover the _same_ region of the genome (the upstream filtering stuff should already guarantee this), but this is about as far as we go. (We could also probably filter out supplementary alignments entirely and I suspect that wouldn't change the results here much.)

# %%
# Maps sequence IDs to genes (keyed by their Index in the .sco file) to codons (keyed by (0-indexed!)
# left end, i.e. the lower of the two positional boundaries of the codon, regardless of if its gene
# is on the + or - strand) to observed aligned codon frequencies (keyed by just the triplet, e.g. "AAA").
#
# Example:
# {"edge_6104":                                Sequence
#     {1:                                      Gene index in the .sco file
#         {265:                                Left codon position
#             {"TTA": 1000, "TTT": 1, ... }    Aligned codon frequencies for this particular codon
#         }
#     }
# }
seq2gene2codon2alignedcodons = {}

# %%
bf = pysam.AlignmentFile("../main-workflow/output/fully-filtered-and-sorted-aln.bam", "rb")

tT1 = time.time()
for seq in SEQS:
    df = parse_sco("../seqs/genes/{}.sco".format(seq))
    
    # We don't actually store any results in this, but we do use it for a slight optimization
    gene2isrev = {}
    
    # Initialize some of the data structures
    # NOTE: this is kind of slow. However, it still finishes within a few seconds, so not the most
    # important thing to optimize
    seq2gene2codon2alignedcodons[seq] = {}
    for gene_data in df.itertuples():
        
        validate_gene_coords(gene_data)        
        seq2gene2codon2alignedcodons[seq][gene_data.Index] = {}
        gene2isrev[gene_data.Index] = (gene_data.Strand == "-")
        
        codon_positions = get_gene_left_codon_positions(gene_data)

        # For each codon in this gene, keep track of all the codons spanning it from the various
        # alignments to this genome.
        for cpleft in codon_positions:
            seq2gene2codon2alignedcodons[seq][gene_data.Index][cpleft] = defaultdict(int)
            
    print("Finished initialization for seq = {}".format(seq))
    alntimes = []
    
    for ri, aln in enumerate(bf.fetch(seq), 1):
        
        t1 = time.time()
        
        # Find all genes that this aln intersects in this genome
        
        # These are 0-indexed coordinates (and segright is offset to the right by one; see
        # https://pysam.readthedocs.io/en/latest/api.html#pysam.AlignedSegment.reference_end)
        segleft = aln.reference_start
        segright = aln.reference_end
        
        if segleft is None or segright is None:
            raise ValueError("Read {} is unmapped? This shouldn't happen!".format(seg.query_name))
        
        if segleft >= segright:
            raise ValueError("Read {}'s coordinates in pysam seem messed up: left = {}, right = {}".format(
                seg.query_name, segleft, segright
            ))
        
        # Convert aligned segment boundaries to 1-indexed coordinates to make comparing with gene
        # coordinates from the .sco file easier.
        # Since segright was already offset to the right by 1, we don't need to do anything for it
        # (the gene coordinates are exact: a gene from [266, 712] starts at base 266 and ends at base 712,
        # using 1-indexing. So in order to make the aln boundaries match, we'd add 1 for segright and then
        # subract 1 since segright was already 1 base off -- and n + 1 - 1 = n. (...math is hard)
        segleft += 1
        
        # Use vectorization to find genes overlapping this aln: see https://stackoverflow.com/a/17071908
        # for details on why parentheses, etc., and
        # https://engineering.upside.com/a-beginners-guide-to-optimizing-pandas-code-for-speed-c09ef2c6a4d6
        # for justification on why this is useful (tldr: makes code go fast)
        genes_overlapping_aln = list(
            df.loc[(df["RightEnd"] >= segleft) & (df["LeftEnd"] <= segright)].itertuples()
        )
        # Note about the above thing that just happened: you may be shaking your fist and saying "wait
        # itertuples is slow!" And yeah, kinda. But for whatever reason I've tried multiple times to keep
        # genes_overlapping_aln as a DataFrame (and then later vectorize stuff like checking that a given
        # aligned pair covers a codon within the genes, etc) and the overhead costs seem to slow things down.
        # I am sure it's possible to speed things up more, but right now things seem good enough.

        # (Debugging code)
        # print("{} genes overlap aln {}".format(len(genes_overlapping_aln), ri))
        # print("Read {}, which ranges from {} to {}, overlaps these genes:".format(ri, segleft, segright))
        # print(genes_overlapping_aln)
                
        # If no genes overlap this aln, we are free to move on to the next aln.
        if len(genes_overlapping_aln) > 0:
            
            # Computing this is relatively slow, which is why we jump through so many hoops before we do this.
            # Each entry in get_aligned_pairs() is a tuple with 2 elements:
            # the first is the query/read pos and the second is the reference pos.
            # TODO: would it be possible to only do this for certain positions we care about? get_aligned_pairs()
            # returns a lot of stuff we don't need, e.g. regions of the aln that don't intersect with any genes.
            ap = aln.get_aligned_pairs(matches_only=True)
            
            # Doesn't look like getting this in advance saves much time, but I don't think it hurts.
            read_seq = aln.query_sequence
            
            # We only consider the leftmost position of each codon, so we don't need to bother checking the last
            # two pairs of positions (since neither could be the leftmost position of a codon that this aln
            # fully covers).
            for api, pair1 in enumerate(ap[:-2]):

                # Convert to 1-indexed position for ease of comparison with gene coordinates
                pair1_refpos = pair1[1] + 1
                  
                havent_checked_next_pairs = True
                for gene_data in genes_overlapping_aln:
                    gl = gene_data.LeftEnd
                    gr = gene_data.RightEnd
                    
                    # Check that this pair is located within this gene and is the leftmost position of a
                    # codon in the gene. (Note that this check works for both + or - strand genes.
                    # Whether the leftmost position is the "start" [i.e. CP 1] or "end" [i.e. CP 3] of
                    # the gene changes with the strand of the gene, but we'll account for that later on
                    # when we reverse-complement the codon if needed.)
                    if pair1_refpos >= gl and pair1_refpos <= gr - 2 and ((pair1_refpos - gl) % 3 == 0):
                        
                        # Nice! Looks like this aln fully covers this codon.
                        
                        # If we haven't yet, check that this aln doesn't skip over parts of the codon,
                        # or stuff like that. The reason this check is located *here* (and not
                        # before we loop over the genes) is that it seems like this is a faster strategy:
                        # only run these checks once we KNOW that this pair looks like it fully covers a
                        # codon, since many pairs might not meet that criteria.
                        #
                        # (And by recording that we've run this check once, in havent_checked_next_pairs,
                        # we can save the time cost of running the check multiple times.)
                        #
                        # I feel like an insane person trying to optimize this so much lmao.
                        if havent_checked_next_pairs:
                            # Check that the pairs are all consecutive (i.e. no "jumps" in the read,
                            # and no "jumps" in the reference)
                            # Since we don't consider the last two pairs in ap, pair2 and pair3 should
                            # always be available.
                            pair2 = ap[api + 1]
                            pair3 = ap[api + 2]

                            # For an aligned pair, [0] is the read pos and [1] is the reference pos.
                            # Result of caching this is probably negligible but... may as well
                            p10 = pair1[0]
                            p20 = pair2[0]
                            readpos_consecutive = p20 == (p10 + 1) and pair3[0] == (p20 + 1)
                            if not readpos_consecutive:
                                break

                            # (pair1_refpos is already off by 1 so no need to redo the addition operation)
                            p21 = pair2[1]
                            refpos_consecutive = p21 == pair1_refpos and pair3[1] == (p21 + 1)
                            if not refpos_consecutive:
                                break
                            havent_checked_next_pairs = False
                        
                        # Figure out what the read actually *says* in the alignment here.
                        # (It'll probably be a complete match most of the time, but there will
                        # be some occasional mismatches -- and seeing those is ... the whole point
                        # of this notebook.)

                        # We make sure to index the read by read coords, not reference coords!
                        aligned_codon = read_seq[p10: p10 + 3]

                        # Finally, update information about codon frequencies.
                        gi = gene_data.Index
                        if gene2isrev[gi]:
                            seq2gene2codon2alignedcodons[seq][gi][pair1_refpos][codon2revcomp[aligned_codon]] += 1
                        else:
                            seq2gene2codon2alignedcodons[seq][gi][pair1_refpos][aligned_codon] += 1

        t2 = time.time()
        alntimes.append(t2 - t1)
        # the downside to printing frequent messages is that it inflates the notebook filesize, which can
        # be annoying. hence less frequent messages here (every 10k alignments).
        if ri % 10000 == 0:
            print(f"Seen {ri:,} alignments so far in {seq}.")
            print(f"Total time taken thus far:               {t2-tT1:,.4f} sec.")
            print(f"Average time per alignment for this seq: {mean(alntimes):,.4f} sec.")

    # At this point, we've seen all the alignments to all the codons in this genome.
    # We can now "call" mutations based on the frequencies we've counted.
tT2 = time.time()

print("Figuring all that out took a total of {} seconds.".format(tT2 - tT1))

bf.close()
# TODO: It'd probably be safer to output this after each sequence, rather than at the very end.
with open("matrix-jsons/seq2gene2codon2alignedcodons.json", "w") as dumpster:
    dumpster.write(json.dumps(seq2gene2codon2alignedcodons))
# Out:
# Finished initialization for seq = edge_6104
# Seen 10,000 alignments so far in edge_6104.
# Total time taken thus far:               533.4696 sec.
# Average time per alignment for this seq: 0.0531 sec.
# Seen 20,000 alignments so far in edge_6104.
# Total time taken thus far:               1,210.8409 sec.
# Average time per alignment for this seq: 0.0604 sec.
# Seen 30,000 alignments so far in edge_6104.
# Total time taken thus far:               1,881.3421 sec.
# Average time per alignment for this seq: 0.0626 sec.
# Seen 40,000 alignments so far in edge_6104.
# Total time taken thus far:               2,390.0748 sec.
# Average time per alignment for this seq: 0.0596 sec.
# Seen 50,000 alignments so far in edge_6104.
# Total time taken thus far:               2,848.1760 sec.
# Average time per alignment for this seq: 0.0569 sec.
# Seen 60,000 alignments so far in edge_6104.
# Total time taken thus far:               3,341.7460 sec.
# Average time per alignment for this seq: 0.0556 sec.
# Seen 70,000 alignments so far in edge_6104.
# Total time taken thus far:               3,853.8554 sec.
# Average time per alignment for this seq: 0.0550 sec.
# Seen 80,000 alignments so far in edge_6104.
# Total time taken thus far:               4,327.7412 sec.
# Average time per alignment for this seq: 0.0540 sec.
# Seen 90,000 alignments so far in edge_6104.
# Total time taken thus far:               4,794.8976 sec.
# Average time per alignment for this seq: 0.0532 sec.
# Seen 100,000 alignments so far in edge_6104.
# Total time taken thus far:               5,246.1620 sec.
# Average time per alignment for this seq: 0.0524 sec.
# Seen 110,000 alignments so far in edge_6104.
# Total time taken thus far:               5,714.2607 sec.
# Average time per alignment for this seq: 0.0519 sec.
# Seen 120,000 alignments so far in edge_6104.
# Total time taken thus far:               6,197.4528 sec.
# Average time per alignment for this seq: 0.0516 sec.
# Seen 130,000 alignments so far in edge_6104.
# Total time taken thus far:               6,673.7046 sec.
# Average time per alignment for this seq: 0.0513 sec.
# Seen 140,000 alignments so far in edge_6104.
# Total time taken thus far:               7,181.5037 sec.
# Average time per alignment for this seq: 0.0512 sec.
# Seen 150,000 alignments so far in edge_6104.
# Total time taken thus far:               7,648.3096 sec.
# Average time per alignment for this seq: 0.0509 sec.
# Seen 160,000 alignments so far in edge_6104.
# Total time taken thus far:               8,092.0772 sec.
# Average time per alignment for this seq: 0.0505 sec.
# Seen 170,000 alignments so far in edge_6104.
# Total time taken thus far:               8,547.8287 sec.
# Average time per alignment for this seq: 0.0502 sec.
# Seen 180,000 alignments so far in edge_6104.
# Total time taken thus far:               9,026.3488 sec.
# Average time per alignment for this seq: 0.0501 sec.
# Seen 190,000 alignments so far in edge_6104.
# Total time taken thus far:               9,522.9231 sec.
# Average time per alignment for this seq: 0.0500 sec.
# Seen 200,000 alignments so far in edge_6104.
# Total time taken thus far:               10,029.1408 sec.
# Average time per alignment for this seq: 0.0501 sec.
# Seen 210,000 alignments so far in edge_6104.
# Total time taken thus far:               10,622.7123 sec.
# Average time per alignment for this seq: 0.0505 sec.
# Seen 220,000 alignments so far in edge_6104.
# Total time taken thus far:               11,335.8687 sec.
# Average time per alignment for this seq: 0.0514 sec.
# Seen 230,000 alignments so far in edge_6104.
# Total time taken thus far:               11,964.2821 sec.
# Average time per alignment for this seq: 0.0519 sec.
# Seen 240,000 alignments so far in edge_6104.
# Total time taken thus far:               12,691.2183 sec.
# Average time per alignment for this seq: 0.0528 sec.
# Seen 250,000 alignments so far in edge_6104.
# Total time taken thus far:               13,340.6264 sec.
# Average time per alignment for this seq: 0.0533 sec.
# Seen 260,000 alignments so far in edge_6104.
# Total time taken thus far:               13,899.5399 sec.
# Average time per alignment for this seq: 0.0534 sec.
# Seen 270,000 alignments so far in edge_6104.
# Total time taken thus far:               14,427.3055 sec.
# Average time per alignment for this seq: 0.0533 sec.
# Seen 280,000 alignments so far in edge_6104.
# Total time taken thus far:               14,916.2138 sec.
# Average time per alignment for this seq: 0.0532 sec.
# Seen 290,000 alignments so far in edge_6104.
# Total time taken thus far:               15,439.1755 sec.
# Average time per alignment for this seq: 0.0532 sec.
# Seen 300,000 alignments so far in edge_6104.
# Total time taken thus far:               15,931.3613 sec.
# Average time per alignment for this seq: 0.0530 sec.
# Seen 310,000 alignments so far in edge_6104.
# Total time taken thus far:               16,438.8805 sec.
# Average time per alignment for this seq: 0.0529 sec.
# Seen 320,000 alignments so far in edge_6104.
# Total time taken thus far:               16,923.2639 sec.
# Average time per alignment for this seq: 0.0528 sec.
# Seen 330,000 alignments so far in edge_6104.
# Total time taken thus far:               17,393.4052 sec.
# Average time per alignment for this seq: 0.0526 sec.
# Seen 340,000 alignments so far in edge_6104.
# Total time taken thus far:               17,874.5265 sec.
# Average time per alignment for this seq: 0.0525 sec.
# Seen 350,000 alignments so far in edge_6104.
# Total time taken thus far:               18,303.1572 sec.
# Average time per alignment for this seq: 0.0522 sec.
# Seen 360,000 alignments so far in edge_6104.
# Total time taken thus far:               18,933.1063 sec.
# Average time per alignment for this seq: 0.0525 sec.
# Seen 370,000 alignments so far in edge_6104.
# Total time taken thus far:               19,547.9468 sec.
# Average time per alignment for this seq: 0.0527 sec.
# Seen 380,000 alignments so far in edge_6104.
# Total time taken thus far:               20,032.8504 sec.
# Average time per alignment for this seq: 0.0526 sec.
# Seen 390,000 alignments so far in edge_6104.
# Total time taken thus far:               20,483.7140 sec.
# Average time per alignment for this seq: 0.0524 sec.
# Seen 400,000 alignments so far in edge_6104.
# Total time taken thus far:               21,011.6302 sec.
# Average time per alignment for this seq: 0.0524 sec.
# Seen 410,000 alignments so far in edge_6104.
# Total time taken thus far:               21,518.9436 sec.
# Average time per alignment for this seq: 0.0524 sec.
# Seen 420,000 alignments so far in edge_6104.
# Total time taken thus far:               22,094.9500 sec.
# Average time per alignment for this seq: 0.0525 sec.
# Seen 430,000 alignments so far in edge_6104.
# Total time taken thus far:               22,627.3560 sec.
# Average time per alignment for this seq: 0.0525 sec.
# Seen 440,000 alignments so far in edge_6104.
# Total time taken thus far:               23,161.1085 sec.
# Average time per alignment for this seq: 0.0525 sec.
# Seen 450,000 alignments so far in edge_6104.
# Total time taken thus far:               23,689.5361 sec.
# Average time per alignment for this seq: 0.0526 sec.
# Seen 460,000 alignments so far in edge_6104.
# Total time taken thus far:               24,192.0448 sec.
# Average time per alignment for this seq: 0.0525 sec.
# Seen 470,000 alignments so far in edge_6104.
# Total time taken thus far:               24,671.7797 sec.
# Average time per alignment for this seq: 0.0524 sec.
# Finished initialization for seq = edge_1671
# Seen 10,000 alignments so far in edge_1671.
# Total time taken thus far:               25,491.3871 sec.
# Average time per alignment for this seq: 0.0541 sec.
# Seen 20,000 alignments so far in edge_1671.
# Total time taken thus far:               25,915.2615 sec.
# Average time per alignment for this seq: 0.0482 sec.
# Seen 30,000 alignments so far in edge_1671.
# Total time taken thus far:               26,396.1758 sec.
# Average time per alignment for this seq: 0.0481 sec.
# Seen 40,000 alignments so far in edge_1671.
# Total time taken thus far:               26,922.6191 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Seen 50,000 alignments so far in edge_1671.
# Total time taken thus far:               27,375.9528 sec.
# Average time per alignment for this seq: 0.0484 sec.
# Seen 60,000 alignments so far in edge_1671.
# Total time taken thus far:               27,833.0469 sec.
# Average time per alignment for this seq: 0.0480 sec.
# Seen 70,000 alignments so far in edge_1671.
# Total time taken thus far:               28,269.8448 sec.
# Average time per alignment for this seq: 0.0474 sec.
# Seen 80,000 alignments so far in edge_1671.
# Total time taken thus far:               28,751.4656 sec.
# Average time per alignment for this seq: 0.0474 sec.
# Seen 90,000 alignments so far in edge_1671.
# Total time taken thus far:               29,214.3313 sec.
# Average time per alignment for this seq: 0.0473 sec.
# Seen 100,000 alignments so far in edge_1671.
# Total time taken thus far:               29,722.0808 sec.
# Average time per alignment for this seq: 0.0476 sec.
# Seen 110,000 alignments so far in edge_1671.
# Total time taken thus far:               30,260.7548 sec.
# Average time per alignment for this seq: 0.0482 sec.
# Seen 120,000 alignments so far in edge_1671.
# Total time taken thus far:               30,775.0755 sec.
# Average time per alignment for this seq: 0.0485 sec.
# Seen 130,000 alignments so far in edge_1671.
# Total time taken thus far:               31,248.5773 sec.
# Average time per alignment for this seq: 0.0484 sec.
# Seen 140,000 alignments so far in edge_1671.
# Total time taken thus far:               31,758.4558 sec.
# Average time per alignment for this seq: 0.0486 sec.
# Seen 150,000 alignments so far in edge_1671.
# Total time taken thus far:               32,136.1669 sec.
# Average time per alignment for this seq: 0.0478 sec.
# Seen 160,000 alignments so far in edge_1671.
# Total time taken thus far:               32,599.5877 sec.
# Average time per alignment for this seq: 0.0477 sec.
# Seen 170,000 alignments so far in edge_1671.
# Total time taken thus far:               33,123.8953 sec.
# Average time per alignment for this seq: 0.0480 sec.
# Seen 180,000 alignments so far in edge_1671.
# Total time taken thus far:               33,544.1661 sec.
# Average time per alignment for this seq: 0.0477 sec.
# Seen 190,000 alignments so far in edge_1671.
# Total time taken thus far:               33,996.6535 sec.
# Average time per alignment for this seq: 0.0475 sec.
# Seen 200,000 alignments so far in edge_1671.
# Total time taken thus far:               34,429.1744 sec.
# Average time per alignment for this seq: 0.0473 sec.
# Seen 210,000 alignments so far in edge_1671.
# Total time taken thus far:               34,859.8427 sec.
# Average time per alignment for this seq: 0.0471 sec.
# Seen 220,000 alignments so far in edge_1671.
# Total time taken thus far:               35,303.6419 sec.
# Average time per alignment for this seq: 0.0470 sec.
# Seen 230,000 alignments so far in edge_1671.
# Total time taken thus far:               35,790.5516 sec.
# Average time per alignment for this seq: 0.0471 sec.
# Seen 240,000 alignments so far in edge_1671.
# Total time taken thus far:               36,262.0926 sec.
# Average time per alignment for this seq: 0.0471 sec.
# Seen 250,000 alignments so far in edge_1671.
# Total time taken thus far:               36,710.8298 sec.
# Average time per alignment for this seq: 0.0470 sec.
# Seen 260,000 alignments so far in edge_1671.
# Total time taken thus far:               37,134.4914 sec.
# Average time per alignment for this seq: 0.0468 sec.
# Finished initialization for seq = edge_2358
# Seen 10,000 alignments so far in edge_2358.
# Total time taken thus far:               37,618.7759 sec.
# Average time per alignment for this seq: 0.0371 sec.
# Seen 20,000 alignments so far in edge_2358.
# Total time taken thus far:               38,136.3668 sec.
# Average time per alignment for this seq: 0.0444 sec.
# Seen 30,000 alignments so far in edge_2358.
# Total time taken thus far:               38,695.7345 sec.
# Average time per alignment for this seq: 0.0482 sec.
# Seen 40,000 alignments so far in edge_2358.
# Total time taken thus far:               39,127.2728 sec.
# Average time per alignment for this seq: 0.0469 sec.
# Seen 50,000 alignments so far in edge_2358.
# Total time taken thus far:               39,635.9274 sec.
# Average time per alignment for this seq: 0.0477 sec.
# Seen 60,000 alignments so far in edge_2358.
# Total time taken thus far:               40,249.2406 sec.
# Average time per alignment for this seq: 0.0500 sec.
# Seen 70,000 alignments so far in edge_2358.
# Total time taken thus far:               40,740.1838 sec.
# Average time per alignment for this seq: 0.0498 sec.
# Seen 80,000 alignments so far in edge_2358.
# Total time taken thus far:               41,282.7571 sec.
# Average time per alignment for this seq: 0.0504 sec.
# Seen 90,000 alignments so far in edge_2358.
# Total time taken thus far:               41,819.9542 sec.
# Average time per alignment for this seq: 0.0507 sec.
# Seen 100,000 alignments so far in edge_2358.
# Total time taken thus far:               42,374.5923 sec.
# Average time per alignment for this seq: 0.0512 sec.
# Seen 110,000 alignments so far in edge_2358.
# Total time taken thus far:               42,933.0258 sec.
# Average time per alignment for this seq: 0.0516 sec.
# Seen 120,000 alignments so far in edge_2358.
# Total time taken thus far:               43,477.5260 sec.
# Average time per alignment for this seq: 0.0518 sec.
# Seen 130,000 alignments so far in edge_2358.
# Total time taken thus far:               43,994.8932 sec.
# Average time per alignment for this seq: 0.0518 sec.
# Seen 140,000 alignments so far in edge_2358.
# Total time taken thus far:               44,495.2789 sec.
# Average time per alignment for this seq: 0.0517 sec.
# Seen 150,000 alignments so far in edge_2358.
# Total time taken thus far:               44,983.2214 sec.
# Average time per alignment for this seq: 0.0515 sec.
# Seen 160,000 alignments so far in edge_2358.
# Total time taken thus far:               45,489.6275 sec.
# Average time per alignment for this seq: 0.0514 sec.
# Seen 170,000 alignments so far in edge_2358.
# Total time taken thus far:               45,972.2870 sec.
# Average time per alignment for this seq: 0.0512 sec.
# Seen 180,000 alignments so far in edge_2358.
# Total time taken thus far:               46,476.4932 sec.
# Average time per alignment for this seq: 0.0512 sec.
# Seen 190,000 alignments so far in edge_2358.
# Total time taken thus far:               46,922.1239 sec.
# Average time per alignment for this seq: 0.0508 sec.
# Seen 200,000 alignments so far in edge_2358.
# Total time taken thus far:               47,435.0264 sec.
# Average time per alignment for this seq: 0.0509 sec.
# Seen 210,000 alignments so far in edge_2358.
# Total time taken thus far:               47,918.9038 sec.
# Average time per alignment for this seq: 0.0507 sec.
# Seen 220,000 alignments so far in edge_2358.
# Total time taken thus far:               48,412.6222 sec.
# Average time per alignment for this seq: 0.0507 sec.
# Seen 230,000 alignments so far in edge_2358.
# Total time taken thus far:               48,937.1494 sec.
# Average time per alignment for this seq: 0.0507 sec.
# Seen 240,000 alignments so far in edge_2358.
# Total time taken thus far:               49,433.4544 sec.
# Average time per alignment for this seq: 0.0507 sec.
# Seen 250,000 alignments so far in edge_2358.
# Total time taken thus far:               49,990.2162 sec.
# Average time per alignment for this seq: 0.0509 sec.
# Seen 260,000 alignments so far in edge_2358.
# Total time taken thus far:               50,446.4259 sec.
# Average time per alignment for this seq: 0.0507 sec.
# Seen 270,000 alignments so far in edge_2358.
# Total time taken thus far:               50,876.4518 sec.
# Average time per alignment for this seq: 0.0504 sec.
# Seen 280,000 alignments so far in edge_2358.
# Total time taken thus far:               51,280.5973 sec.
# Average time per alignment for this seq: 0.0500 sec.
# Seen 290,000 alignments so far in edge_2358.
# Total time taken thus far:               51,763.3486 sec.
# Average time per alignment for this seq: 0.0500 sec.
# Seen 300,000 alignments so far in edge_2358.
# Total time taken thus far:               52,151.9240 sec.
# Average time per alignment for this seq: 0.0496 sec.
# Seen 310,000 alignments so far in edge_2358.
# Total time taken thus far:               52,627.8249 sec.
# Average time per alignment for this seq: 0.0495 sec.
# Seen 320,000 alignments so far in edge_2358.
# Total time taken thus far:               53,072.6145 sec.
# Average time per alignment for this seq: 0.0494 sec.
# Seen 330,000 alignments so far in edge_2358.
# Total time taken thus far:               53,505.8972 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Seen 340,000 alignments so far in edge_2358.
# Total time taken thus far:               53,987.2661 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Seen 350,000 alignments so far in edge_2358.
# Total time taken thus far:               54,469.8777 sec.
# Average time per alignment for this seq: 0.0491 sec.
# Seen 360,000 alignments so far in edge_2358.
# Total time taken thus far:               54,995.4217 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Seen 370,000 alignments so far in edge_2358.
# Total time taken thus far:               55,449.4434 sec.
# Average time per alignment for this seq: 0.0491 sec.
# Seen 380,000 alignments so far in edge_2358.
# Total time taken thus far:               55,896.1677 sec.
# Average time per alignment for this seq: 0.0490 sec.
# Seen 390,000 alignments so far in edge_2358.
# Total time taken thus far:               56,350.1083 sec.
# Average time per alignment for this seq: 0.0489 sec.
# Seen 400,000 alignments so far in edge_2358.
# Total time taken thus far:               56,810.9449 sec.
# Average time per alignment for this seq: 0.0488 sec.
# Seen 410,000 alignments so far in edge_2358.
# Total time taken thus far:               57,304.7930 sec.
# Average time per alignment for this seq: 0.0488 sec.
# Seen 420,000 alignments so far in edge_2358.
# Total time taken thus far:               57,856.6473 sec.
# Average time per alignment for this seq: 0.0490 sec.
# Seen 430,000 alignments so far in edge_2358.
# Total time taken thus far:               58,404.8829 sec.
# Average time per alignment for this seq: 0.0491 sec.
# Seen 440,000 alignments so far in edge_2358.
# Total time taken thus far:               59,042.1311 sec.
# Average time per alignment for this seq: 0.0494 sec.
# Seen 450,000 alignments so far in edge_2358.
# Total time taken thus far:               59,469.2737 sec.
# Average time per alignment for this seq: 0.0493 sec.
# Seen 460,000 alignments so far in edge_2358.
# Total time taken thus far:               59,945.7898 sec.
# Average time per alignment for this seq: 0.0493 sec.
# Seen 470,000 alignments so far in edge_2358.
# Total time taken thus far:               60,423.2775 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Seen 480,000 alignments so far in edge_2358.
# Total time taken thus far:               60,876.2429 sec.
# Average time per alignment for this seq: 0.0491 sec.
# Seen 490,000 alignments so far in edge_2358.
# Total time taken thus far:               61,344.3938 sec.
# Average time per alignment for this seq: 0.0491 sec.
# Seen 500,000 alignments so far in edge_2358.
# Total time taken thus far:               61,818.8598 sec.
# Average time per alignment for this seq: 0.0491 sec.
# Seen 510,000 alignments so far in edge_2358.
# Total time taken thus far:               62,227.8876 sec.
# Average time per alignment for this seq: 0.0489 sec.
# Seen 520,000 alignments so far in edge_2358.
# Total time taken thus far:               62,678.8304 sec.
# Average time per alignment for this seq: 0.0488 sec.
# Seen 530,000 alignments so far in edge_2358.
# Total time taken thus far:               63,119.4522 sec.
# Average time per alignment for this seq: 0.0487 sec.
# Seen 540,000 alignments so far in edge_2358.
# Total time taken thus far:               63,582.7566 sec.
# Average time per alignment for this seq: 0.0487 sec.
# Seen 550,000 alignments so far in edge_2358.
# Total time taken thus far:               64,117.8373 sec.
# Average time per alignment for this seq: 0.0488 sec.
# Seen 560,000 alignments so far in edge_2358.
# Total time taken thus far:               64,641.1775 sec.
# Average time per alignment for this seq: 0.0488 sec.
# Seen 570,000 alignments so far in edge_2358.
# Total time taken thus far:               65,103.9864 sec.
# Average time per alignment for this seq: 0.0488 sec.
# Seen 580,000 alignments so far in edge_2358.
# Total time taken thus far:               65,556.2930 sec.
# Average time per alignment for this seq: 0.0487 sec.
# Seen 590,000 alignments so far in edge_2358.
# Total time taken thus far:               66,008.6585 sec.
# Average time per alignment for this seq: 0.0487 sec.
# Seen 600,000 alignments so far in edge_2358.
# Total time taken thus far:               66,516.9998 sec.
# Average time per alignment for this seq: 0.0487 sec.
# Seen 610,000 alignments so far in edge_2358.
# Total time taken thus far:               67,008.3701 sec.
# Average time per alignment for this seq: 0.0487 sec.
# Seen 620,000 alignments so far in edge_2358.
# Total time taken thus far:               67,500.3919 sec.
# Average time per alignment for this seq: 0.0487 sec.
# Seen 630,000 alignments so far in edge_2358.
# Total time taken thus far:               67,924.0919 sec.
# Average time per alignment for this seq: 0.0486 sec.
# Seen 640,000 alignments so far in edge_2358.
# Total time taken thus far:               68,374.2986 sec.
# Average time per alignment for this seq: 0.0485 sec.
# Seen 650,000 alignments so far in edge_2358.
# Total time taken thus far:               68,910.9136 sec.
# Average time per alignment for this seq: 0.0486 sec.
# Seen 660,000 alignments so far in edge_2358.
# Total time taken thus far:               69,532.7639 sec.
# Average time per alignment for this seq: 0.0488 sec.
# Seen 670,000 alignments so far in edge_2358.
# Total time taken thus far:               70,081.8715 sec.
# Average time per alignment for this seq: 0.0489 sec.
# Seen 680,000 alignments so far in edge_2358.
# Total time taken thus far:               70,713.0855 sec.
# Average time per alignment for this seq: 0.0491 sec.
# Seen 690,000 alignments so far in edge_2358.
# Total time taken thus far:               71,425.4068 sec.
# Average time per alignment for this seq: 0.0494 sec.
# Seen 700,000 alignments so far in edge_2358.
# Total time taken thus far:               71,883.1156 sec.
# Average time per alignment for this seq: 0.0494 sec.
# Seen 710,000 alignments so far in edge_2358.
# Total time taken thus far:               72,335.0701 sec.
# Average time per alignment for this seq: 0.0493 sec.
# Seen 720,000 alignments so far in edge_2358.
# Total time taken thus far:               72,763.5163 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Seen 730,000 alignments so far in edge_2358.
# Total time taken thus far:               73,211.4630 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Seen 740,000 alignments so far in edge_2358.
# Total time taken thus far:               73,704.6805 sec.
# Average time per alignment for this seq: 0.0492 sec.
# Figuring all that out took a total of 73756.03212618828 seconds.

# %% [markdown]
# ## Using the information we just computed for each genome, "call" mutations and store this information in the frequency data structures we set up earlier
#
# This section is kind of slow, but on the order of "takes a few minutes on the cluster" and not on the order of "takes literally hours to run" (the stuff we just finished doing takes way longer). We could make this next step more efficient if desired; most of my energy on optimization here thus far has been spent on the earlier step in this notebook.
#
# Note that the main output of the above section (`seq2gene2codon2alignedcodons`) has already been written out to a JSON file -- in practice, it's useful to be able to start execution again from this bottom section after stopping the above section (e.g. if something goes wrong _here_, then we don't have to rerun the top part of this notebook again). Even if the entire notebook is run in a single shot, we still save and then load the `seq2gene2codon2alignedcodons` object anyway.

# %%
with open("matrix-jsons/seq2gene2codon2alignedcodons.json", "r") as loadster:
    seq2gene2codon2alignedcodons = json.load(loadster)

# %%
def generate_mutmatrix_data(seq):
    fasta = skbio.DNA.read("../seqs/{}.fasta".format(seq))
    df = parse_sco("../seqs/genes/{}.sco".format(seq))
    
    # 64x63 dict: each key is a triplet of {A, C, G, T}, and each value is another dict with all the other codons
    codon2codon2freq = {}

    # 21x20 dict: each key is a proteinogenic amino acid (A, C, D, E, F, ...), limited to just
    # stuff in the standard genetic code (i.e. ignoring selenocystine and pyrrolsine) but including
    # "*", representing a stop codon.
    aa2aa2freq = {}

    # 64-key dict: maps each triplet to an integer indicating how frequently this triplet occurs in all genes
    # in the genomes (i.e. not counting mutations into this triplet).
    codon2freq = {}

    # 21-key dict: maps amino acid/stop codon to integer indicating frequency across all genes.
    aa2freq = {}

    aas = set([])
    for c in codons:
        aas.add(str(skbio.DNA(c).translate()))

    # Initialize dicts to 0s
    for c1 in codons:
        codon2codon2freq[c1] = {c2: 0 for c2 in set(codons) - set([c1])}
        codon2freq[c1] = 0

    for aa1 in aas:
        aa2aa2freq[aa1] = {aa2: 0 for aa2 in set(aas) - set([aa1])}
        aa2freq[aa1] = 0   
    
    for gene_data in df.itertuples():
        print("On gene {} in seq {}.".format(gene_data.Index, seq))
        for cpleft in range(gene_data.LeftEnd, gene_data.RightEnd + 1, 3):
            
            # Make note of the codon sequence and amino acid encoded by this codon in the "reference" genome.
            # (Keep in mind that the gene data in the .sco file uses 1-indexed coords, so we need to convert
            # accordingly.)
            codon_dna = fasta[cpleft - 1: cpleft + 2]
            if gene_data.Strand == "-":
                codon_dna = codon_dna.reverse_complement()

            codon_seq = str(codon_dna)
            aa = str(codon_dna.translate())
            
            # Update frequencies accordingly.
            codon2freq[codon_seq] += 1
            aa2freq[aa] += 1
            
            # We can finally compute stats re: number of mismatching and matching codons.
            aligned_codons = seq2gene2codon2alignedcodons[seq][str(gene_data.Index)][str(cpleft)]
            
            # Ignore weird, low-coverage cases. We require that the ref codon is both present in the
            # aligned codons and is (one of) the most common aligned codons (it's ok if it is tied with
            # other codon(s) as the most common). See paper for a description of why this is useful; tldr,
            # it means we can pick the most common non-reference codon and be confident its relative freq is
            # in the range [0%, 50%].
            #
            # We also first account for the case where aligned_codons is empty (i.e. nothing's aligned to
            # this codon), since in that case codon_seq will not be in aligned_codons.
            if len(aligned_codons) > 0:
                max_ac_freq = max(aligned_codons.values())
                if codon_seq in aligned_codons and aligned_codons[codon_seq] == max_ac_freq:
                    num_aligned_codons = sum(aligned_codons.values())

                    # Only call a mutation using the max-freq alt codon, not the sum of all alternate codon freqs.
                    # The max(d, key=d.get) trick is from https://stackoverflow.com/a/280156 (I've used it a lot
                    # here :) Notably, this breaks ties arbitrarily.
                    alt_codons = {c: aligned_codons[c] for c in aligned_codons if c != codon_seq}
                    if len(alt_codons) > 0:
                        max_freq_alt_codon = max(alt_codons, key=aligned_codons.get)
                        max_freq_alt_codon_freq = alt_codons[max_freq_alt_codon]
                    else:
                        # The only codon aligned to this position is the reference codon, so no mutation here.
                        max_freq_alt_codon_freq = 0

                    # print("sum of vals of ac is {}".format(sum(aligned_codons.values())))
                    # print("Codon {} from {} to {} in gene {} in seq {} has mutations: {}".format(
                    #     codon_seq, cpleft, cpleft + 2, gene_data.Index, seq, aligned_codons
                    # ))

                    if pileup.naively_call_mutation_directly(max_freq_alt_codon_freq, num_aligned_codons, 0.5):
                        codon2codon2freq[codon_seq][max_freq_alt_codon] += 1

                        #print(f"{codon_seq}, {aligned_codons}, is mutation! max freq alt codon is {max_freq_alt_codon}")

                        # NOTE: I guess you could argue that we should do this another way, where we actually compute
                        # the translations of all the alt codons and then pick the most common AA/stop codon from there?
                        #
                        # You could argue this either way: doing it based on just the mutated codon keeps the matrices
                        # consistent and lessens the impact of small errors, while taking into account all alt codon
                        # translations could help show weird things where multiple mutations have similar consequences.
                        # Hmm.
                        alt_codon_aa = str(skbio.DNA(max_freq_alt_codon).translate())
                        if alt_codon_aa != aa:
                            aa2aa2freq[aa][alt_codon_aa] += 1
                            # print("Is nonsyn mutation! Alt {} codes for {}; orig coded for {}".format(
                            #     max_freq_alt_codon, alt_codon_aa, aa
                            # ))

    # Write out stuff for further analysis / in case of crisis
    with open(f"matrix-jsons/{seq}-codon2codon2freq.json", "w") as dumpster:
        dumpster.write(json.dumps(codon2codon2freq))

    with open(f"matrix-jsons/{seq}-codon2freq.json", "w") as dumpster:
        dumpster.write(json.dumps(codon2freq))

    with open(f"matrix-jsons/{seq}-aa2aa2freq.json", "w") as dumpster:
        dumpster.write(json.dumps(aa2aa2freq))

# On gene 2055 in seq edge_2358.
# On gene 2056 in seq edge_2358.
# On gene 2057 in seq edge_2358.
# On gene 2058 in seq edge_2358.
# On gene 2059 in seq edge_2358.
# On gene 2060 in seq edge_2358.
# On gene 2061 in seq edge_2358.
# On gene 2062 in seq edge_2358.
# On gene 2063 in seq edge_2358.
# On gene 2064 in seq edge_2358.
# On gene 2065 in seq edge_2358.
# On gene 2066 in seq edge_2358.
# On gene 2067 in seq edge_2358.
# On gene 2068 in seq edge_2358.
# On gene 2069 in seq edge_2358.
# On gene 2070 in seq edge_2358.
# On gene 2071 in seq edge_2358.
# On gene 2072 in seq edge_2358.
# On gene 2073 in seq edge_2358.
# On gene 2074 in seq edge_2358.
# On gene 2075 in seq edge_2358.
# On gene 2076 in seq edge_2358.
# On gene 2077 in seq edge_2358.
# On gene 2078 in seq edge_2358.
# On gene 2079 in seq edge_2358.
# On gene 2080 in seq edge_2358.
# On gene 2081 in seq edge_2358.
# On gene 2082 in seq edge_2358.
# On gene 2083 in seq edge_2358.
# On gene 2084 in seq edge_2358.
# On gene 2085 in seq edge_2358.
# On gene 2086 in seq edge_2358.
# On gene 2087 in seq edge_2358.
# On gene 2088 in seq edge_2358.
# On gene 2089 in seq edge_2358.
# On gene 2090 in seq edge_2358.
# On gene 2091 in seq edge_2358.
# On gene 2092 in seq edge_2358.
# On gene 2093 in seq edge_2358.
# On gene 2094 in seq edge_2358.
# On gene 2095 in seq edge_2358.
# On gene 2096 in seq edge_2358.
# On gene 2097 in seq edge_2358.
# On gene 2098 in seq edge_2358.
# On gene 2099 in seq edge_2358.
# On gene 2100 in seq edge_2358.
# On gene 2101 in seq edge_2358.
# On gene 2102 in seq edge_2358.
# On gene 2103 in seq edge_2358.
# On gene 2104 in seq edge_2358.
# On gene 2105 in seq edge_2358.
# On gene 2106 in seq edge_2358.
# On gene 2107 in seq edge_2358.
# On gene 2108 in seq edge_2358.
# On gene 2109 in seq edge_2358.
# On gene 2110 in seq edge_2358.
# On gene 2111 in seq edge_2358.
# On gene 2112 in seq edge_2358.
# On gene 2113 in seq edge_2358.
# On gene 2114 in seq edge_2358.
# On gene 2115 in seq edge_2358.
# On gene 2116 in seq edge_2358.
# On gene 2117 in seq edge_2358.
# On gene 2118 in seq edge_2358.
# On gene 2119 in seq edge_2358.
# On gene 2120 in seq edge_2358.
# On gene 2121 in seq edge_2358.
# On gene 2122 in seq edge_2358.
# On gene 2123 in seq edge_2358.
# On gene 2124 in seq edge_2358.
# On gene 2125 in seq edge_2358.
# On gene 2126 in seq edge_2358.
# On gene 2127 in seq edge_2358.
# On gene 2128 in seq edge_2358.
# On gene 2129 in seq edge_2358.
# On gene 2130 in seq edge_2358.
# On gene 2131 in seq edge_2358.
# On gene 2132 in seq edge_2358.
# On gene 2133 in seq edge_2358.
# On gene 2134 in seq edge_2358.
# On gene 2135 in seq edge_2358.
# On gene 2136 in seq edge_2358.
# On gene 2137 in seq edge_2358.
# On gene 2138 in seq edge_2358.
# On gene 2139 in seq edge_2358.
# On gene 2140 in seq edge_2358.
# On gene 2141 in seq edge_2358.
# On gene 2142 in seq edge_2358.
# On gene 2143 in seq edge_2358.
# On gene 2144 in seq edge_2358.
# On gene 2145 in seq edge_2358.
# On gene 2146 in seq edge_2358.
# On gene 2147 in seq edge_2358.
# On gene 2148 in seq edge_2358.
# On gene 2149 in seq edge_2358.
# On gene 2150 in seq edge_2358.
# On gene 2151 in seq edge_2358.
# On gene 2152 in seq edge_2358.
# On gene 2153 in seq edge_2358.
# On gene 2154 in seq edge_2358.
# On gene 2155 in seq edge_2358.
# On gene 2156 in seq edge_2358.
# On gene 2157 in seq edge_2358.
# On gene 2158 in seq edge_2358.
# On gene 2159 in seq edge_2358.
# On gene 2160 in seq edge_2358.
# On gene 2161 in seq edge_2358.
# On gene 2162 in seq edge_2358.
# On gene 2163 in seq edge_2358.
# On gene 2164 in seq edge_2358.
# On gene 2165 in seq edge_2358.
# On gene 2166 in seq edge_2358.
# On gene 2167 in seq edge_2358.
# On gene 2168 in seq edge_2358.
# On gene 2169 in seq edge_2358.
# On gene 2170 in seq edge_2358.
# On gene 2171 in seq edge_2358.
# On gene 2172 in seq edge_2358.
# On gene 2173 in seq edge_2358.
# On gene 2174 in seq edge_2358.
# On gene 2175 in seq edge_2358.
# On gene 2176 in seq edge_2358.
# On gene 2177 in seq edge_2358.
# On gene 2178 in seq edge_2358.
# On gene 2179 in seq edge_2358.
# On gene 2180 in seq edge_2358.
# On gene 2181 in seq edge_2358.
# On gene 2182 in seq edge_2358.
# On gene 2183 in seq edge_2358.
# On gene 2184 in seq edge_2358.
# On gene 2185 in seq edge_2358.
# On gene 2186 in seq edge_2358.
# On gene 2187 in seq edge_2358.
# On gene 2188 in seq edge_2358.
# On gene 2189 in seq edge_2358.
# On gene 2190 in seq edge_2358.
# On gene 2191 in seq edge_2358.
# On gene 2192 in seq edge_2358.
# On gene 2193 in seq edge_2358.
# On gene 2194 in seq edge_2358.
# On gene 2195 in seq edge_2358.
# On gene 2196 in seq edge_2358.
# On gene 2197 in seq edge_2358.
# On gene 2198 in seq edge_2358.
# On gene 2199 in seq edge_2358.
# On gene 2200 in seq edge_2358.
# On gene 2201 in seq edge_2358.
# On gene 2202 in seq edge_2358.
# On gene 2203 in seq edge_2358.
# On gene 2204 in seq edge_2358.
# On gene 2205 in seq edge_2358.
# On gene 2206 in seq edge_2358.
# On gene 2207 in seq edge_2358.
# On gene 2208 in seq edge_2358.
# On gene 2209 in seq edge_2358.
# On gene 2210 in seq edge_2358.
# On gene 2211 in seq edge_2358.
# On gene 2212 in seq edge_2358.
# On gene 2213 in seq edge_2358.
# On gene 2214 in seq edge_2358.
# On gene 2215 in seq edge_2358.
# On gene 2216 in seq edge_2358.
# On gene 2217 in seq edge_2358.
# On gene 2218 in seq edge_2358.
# On gene 2219 in seq edge_2358.
# On gene 2220 in seq edge_2358.
# On gene 2221 in seq edge_2358.
# On gene 2222 in seq edge_2358.
# On gene 2223 in seq edge_2358.
# On gene 2224 in seq edge_2358.
# On gene 2225 in seq edge_2358.
# On gene 2226 in seq edge_2358.
# On gene 2227 in seq edge_2358.
# On gene 2228 in seq edge_2358.
# On gene 2229 in seq edge_2358.
# On gene 2230 in seq edge_2358.
# On gene 2231 in seq edge_2358.
# On gene 2232 in seq edge_2358.
# On gene 2233 in seq edge_2358.
# On gene 2234 in seq edge_2358.
# On gene 2235 in seq edge_2358.
# On gene 2236 in seq edge_2358.
# On gene 2237 in seq edge_2358.
# On gene 2238 in seq edge_2358.
# On gene 2239 in seq edge_2358.
# On gene 2240 in seq edge_2358.
# On gene 2241 in seq edge_2358.
# On gene 2242 in seq edge_2358.
# On gene 2243 in seq edge_2358.
# On gene 2244 in seq edge_2358.
# On gene 2245 in seq edge_2358.
# On gene 2246 in seq edge_2358.
# On gene 2247 in seq edge_2358.
# On gene 2248 in seq edge_2358.
# On gene 2249 in seq edge_2358.
# On gene 2250 in seq edge_2358.
# On gene 2251 in seq edge_2358.
# On gene 2252 in seq edge_2358.
# On gene 2253 in seq edge_2358.
# On gene 2254 in seq edge_2358.
# On gene 2255 in seq edge_2358.
# On gene 2256 in seq edge_2358.
# On gene 2257 in seq edge_2358.
# On gene 2258 in seq edge_2358.
# On gene 2259 in seq edge_2358.
# On gene 2260 in seq edge_2358.
# On gene 2261 in seq edge_2358.
# On gene 2262 in seq edge_2358.
# On gene 2263 in seq edge_2358.
# On gene 2264 in seq edge_2358.
# On gene 2265 in seq edge_2358.
# On gene 2266 in seq edge_2358.
# On gene 2267 in seq edge_2358.
# On gene 2268 in seq edge_2358.
# On gene 2269 in seq edge_2358.
# On gene 2270 in seq edge_2358.
# On gene 2271 in seq edge_2358.
# On gene 2272 in seq edge_2358.
# On gene 2273 in seq edge_2358.
# On gene 2274 in seq edge_2358.
# On gene 2275 in seq edge_2358.
# On gene 2276 in seq edge_2358.
# On gene 2277 in seq edge_2358.
# On gene 2278 in seq edge_2358.
# On gene 2279 in seq edge_2358.
# On gene 2280 in seq edge_2358.
# On gene 2281 in seq edge_2358.
# On gene 2282 in seq edge_2358.
# On gene 2283 in seq edge_2358.
# On gene 2284 in seq edge_2358.
# On gene 2285 in seq edge_2358.
# On gene 2286 in seq edge_2358.
# On gene 2287 in seq edge_2358.
# On gene 2288 in seq edge_2358.
# On gene 2289 in seq edge_2358.
# On gene 2290 in seq edge_2358.
# On gene 2291 in seq edge_2358.
# On gene 2292 in seq edge_2358.
# On gene 2293 in seq edge_2358.
# On gene 2294 in seq edge_2358.
# On gene 2295 in seq edge_2358.
# On gene 2296 in seq edge_2358.
# On gene 2297 in seq edge_2358.
# On gene 2298 in seq edge_2358.
# On gene 2299 in seq edge_2358.
# On gene 2300 in seq edge_2358.
# On gene 2301 in seq edge_2358.
# On gene 2302 in seq edge_2358.
# On gene 2303 in seq edge_2358.
# On gene 2304 in seq edge_2358.
# On gene 2305 in seq edge_2358.
# On gene 2306 in seq edge_2358.
# On gene 2307 in seq edge_2358.
# On gene 2308 in seq edge_2358.
# On gene 2309 in seq edge_2358.
# On gene 2310 in seq edge_2358.
# On gene 2311 in seq edge_2358.
# On gene 2312 in seq edge_2358.
# On gene 2313 in seq edge_2358.
# On gene 2314 in seq edge_2358.
# On gene 2315 in seq edge_2358.
# On gene 2316 in seq edge_2358.
# On gene 2317 in seq edge_2358.
# On gene 2318 in seq edge_2358.
# On gene 2319 in seq edge_2358.
# On gene 2320 in seq edge_2358.
# On gene 2321 in seq edge_2358.
# On gene 2322 in seq edge_2358.
# On gene 2323 in seq edge_2358.
# On gene 2324 in seq edge_2358.
# On gene 2325 in seq edge_2358.
# On gene 2326 in seq edge_2358.
# On gene 2327 in seq edge_2358.
# On gene 2328 in seq edge_2358.
# On gene 2329 in seq edge_2358.
# On gene 2330 in seq edge_2358.
# On gene 2331 in seq edge_2358.
# On gene 2332 in seq edge_2358.
# On gene 2333 in seq edge_2358.
# On gene 2334 in seq edge_2358.
# On gene 2335 in seq edge_2358.
# On gene 2336 in seq edge_2358.
# On gene 2337 in seq edge_2358.
# On gene 2338 in seq edge_2358.
# On gene 2339 in seq edge_2358.
# On gene 2340 in seq edge_2358.
# On gene 2341 in seq edge_2358.
# On gene 2342 in seq edge_2358.
# On gene 2343 in seq edge_2358.
# On gene 2344 in seq edge_2358.
# On gene 2345 in seq edge_2358.
# On gene 2346 in seq edge_2358.
# On gene 2347 in seq edge_2358.
# On gene 2348 in seq edge_2358.
# On gene 2349 in seq edge_2358.
# On gene 2350 in seq edge_2358.
# On gene 2351 in seq edge_2358.
# On gene 2352 in seq edge_2358.
# On gene 2353 in seq edge_2358.
# On gene 2354 in seq edge_2358.
# On gene 2355 in seq edge_2358.
# On gene 2356 in seq edge_2358.
# On gene 2357 in seq edge_2358.
# On gene 2358 in seq edge_2358.
# On gene 2359 in seq edge_2358.
# On gene 2360 in seq edge_2358.
# On gene 2361 in seq edge_2358.
# On gene 2362 in seq edge_2358.
# On gene 2363 in seq edge_2358.
# On gene 2364 in seq edge_2358.
# On gene 2365 in seq edge_2358.
# On gene 2366 in seq edge_2358.
# On gene 2367 in seq edge_2358.
# On gene 2368 in seq edge_2358.
# On gene 2369 in seq edge_2358.
# On gene 2370 in seq edge_2358.
# On gene 2371 in seq edge_2358.
# On gene 2372 in seq edge_2358.
# On gene 2373 in seq edge_2358.
# On gene 2374 in seq edge_2358.
# On gene 2375 in seq edge_2358.
# On gene 2376 in seq edge_2358.
# On gene 2377 in seq edge_2358.
# On gene 2378 in seq edge_2358.
# On gene 2379 in seq edge_2358.
# On gene 2380 in seq edge_2358.
# On gene 2381 in seq edge_2358.
# On gene 2382 in seq edge_2358.
# On gene 2383 in seq edge_2358.
# On gene 2384 in seq edge_2358.
# On gene 2385 in seq edge_2358.
# On gene 2386 in seq edge_2358.
# On gene 2387 in seq edge_2358.
# On gene 2388 in seq edge_2358.
# On gene 2389 in seq edge_2358.
# On gene 2390 in seq edge_2358.
# On gene 2391 in seq edge_2358.
# On gene 2392 in seq edge_2358.
# On gene 2393 in seq edge_2358.
# On gene 2394 in seq edge_2358.
# On gene 2395 in seq edge_2358.
# On gene 2396 in seq edge_2358.
# On gene 2397 in seq edge_2358.
# On gene 2398 in seq edge_2358.
# On gene 2399 in seq edge_2358.
# On gene 2400 in seq edge_2358.
# On gene 2401 in seq edge_2358.
# On gene 2402 in seq edge_2358.
# On gene 2403 in seq edge_2358.
# On gene 2404 in seq edge_2358.
# On gene 2405 in seq edge_2358.
# On gene 2406 in seq edge_2358.
# On gene 2407 in seq edge_2358.
# On gene 2408 in seq edge_2358.
# On gene 2409 in seq edge_2358.
# On gene 2410 in seq edge_2358.
# On gene 2411 in seq edge_2358.
# On gene 2412 in seq edge_2358.
# On gene 2413 in seq edge_2358.
# On gene 2414 in seq edge_2358.
# On gene 2415 in seq edge_2358.
# On gene 2416 in seq edge_2358.
# On gene 2417 in seq edge_2358.
# On gene 2418 in seq edge_2358.
# On gene 2419 in seq edge_2358.
# On gene 2420 in seq edge_2358.
# On gene 2421 in seq edge_2358.
# On gene 2422 in seq edge_2358.
# On gene 2423 in seq edge_2358.
# On gene 2424 in seq edge_2358.
# On gene 2425 in seq edge_2358.
# On gene 2426 in seq edge_2358.
# On gene 2427 in seq edge_2358.
# On gene 2428 in seq edge_2358.
# On gene 2429 in seq edge_2358.
# On gene 2430 in seq edge_2358.
# On gene 2431 in seq edge_2358.
# On gene 2432 in seq edge_2358.
# On gene 2433 in seq edge_2358.
# On gene 2434 in seq edge_2358.
# On gene 2435 in seq edge_2358.
# On gene 2436 in seq edge_2358.
# On gene 2437 in seq edge_2358.
# On gene 2438 in seq edge_2358.
# On gene 2439 in seq edge_2358.
# On gene 2440 in seq edge_2358.
# On gene 2441 in seq edge_2358.
# On gene 2442 in seq edge_2358.
# On gene 2443 in seq edge_2358.
# On gene 2444 in seq edge_2358.
# On gene 2445 in seq edge_2358.
# On gene 2446 in seq edge_2358.
# On gene 2447 in seq edge_2358.
# On gene 2448 in seq edge_2358.
# On gene 2449 in seq edge_2358.
# On gene 2450 in seq edge_2358.
# On gene 2451 in seq edge_2358.
# On gene 2452 in seq edge_2358.
# On gene 2453 in seq edge_2358.
# On gene 2454 in seq edge_2358.
# On gene 2455 in seq edge_2358.
# On gene 2456 in seq edge_2358.
# On gene 2457 in seq edge_2358.
# On gene 2458 in seq edge_2358.
# On gene 2459 in seq edge_2358.
# On gene 2460 in seq edge_2358.
# On gene 2461 in seq edge_2358.
# On gene 2462 in seq edge_2358.
# On gene 2463 in seq edge_2358.
# On gene 2464 in seq edge_2358.
# On gene 2465 in seq edge_2358.
# On gene 2466 in seq edge_2358.
# On gene 2467 in seq edge_2358.
# On gene 2468 in seq edge_2358.
# On gene 2469 in seq edge_2358.
# On gene 2470 in seq edge_2358.
# On gene 2471 in seq edge_2358.
# On gene 2472 in seq edge_2358.
# On gene 2473 in seq edge_2358.
# On gene 2474 in seq edge_2358.
# On gene 2475 in seq edge_2358.
# On gene 2476 in seq edge_2358.
# On gene 2477 in seq edge_2358.
# On gene 2478 in seq edge_2358.
# On gene 2479 in seq edge_2358.
# On gene 2480 in seq edge_2358.
# On gene 2481 in seq edge_2358.
# On gene 2482 in seq edge_2358.
# On gene 2483 in seq edge_2358.
# On gene 2484 in seq edge_2358.
# On gene 2485 in seq edge_2358.
# On gene 2486 in seq edge_2358.
# On gene 2487 in seq edge_2358.
# On gene 2488 in seq edge_2358.
# On gene 2489 in seq edge_2358.
# On gene 2490 in seq edge_2358.
# On gene 2491 in seq edge_2358.
# On gene 2492 in seq edge_2358.
# On gene 2493 in seq edge_2358.
# On gene 2494 in seq edge_2358.
# On gene 2495 in seq edge_2358.
# On gene 2496 in seq edge_2358.
# On gene 2497 in seq edge_2358.
# On gene 2498 in seq edge_2358.
# On gene 2499 in seq edge_2358.
# On gene 2500 in seq edge_2358.
# On gene 2501 in seq edge_2358.
# On gene 2502 in seq edge_2358.
# On gene 2503 in seq edge_2358.
# On gene 2504 in seq edge_2358.
# On gene 2505 in seq edge_2358.
# On gene 2506 in seq edge_2358.
# On gene 2507 in seq edge_2358.
# On gene 2508 in seq edge_2358.
# On gene 2509 in seq edge_2358.
# On gene 2510 in seq edge_2358.
# On gene 2511 in seq edge_2358.
# On gene 2512 in seq edge_2358.
# On gene 2513 in seq edge_2358.
# On gene 2514 in seq edge_2358.
# On gene 2515 in seq edge_2358.
# On gene 2516 in seq edge_2358.
# On gene 2517 in seq edge_2358.
# On gene 2518 in seq edge_2358.
# On gene 2519 in seq edge_2358.
# On gene 2520 in seq edge_2358.
# On gene 2521 in seq edge_2358.
# On gene 2522 in seq edge_2358.
# On gene 2523 in seq edge_2358.
# On gene 2524 in seq edge_2358.
# On gene 2525 in seq edge_2358.
# On gene 2526 in seq edge_2358.
# On gene 2527 in seq edge_2358.
# On gene 2528 in seq edge_2358.
# On gene 2529 in seq edge_2358.
# On gene 2530 in seq edge_2358.
# On gene 2531 in seq edge_2358.
# On gene 2532 in seq edge_2358.
# On gene 2533 in seq edge_2358.
# On gene 2534 in seq edge_2358.
# On gene 2535 in seq edge_2358.
# On gene 2536 in seq edge_2358.
# On gene 2537 in seq edge_2358.
# On gene 2538 in seq edge_2358.
# On gene 2539 in seq edge_2358.
# On gene 2540 in seq edge_2358.
# On gene 2541 in seq edge_2358.
# On gene 2542 in seq edge_2358.
# On gene 2543 in seq edge_2358.
# On gene 2544 in seq edge_2358.
# On gene 2545 in seq edge_2358.
# On gene 2546 in seq edge_2358.
# On gene 2547 in seq edge_2358.
# On gene 2548 in seq edge_2358.
# On gene 2549 in seq edge_2358.
# On gene 2550 in seq edge_2358.
# On gene 2551 in seq edge_2358.
# On gene 2552 in seq edge_2358.
# On gene 2553 in seq edge_2358.
# On gene 2554 in seq edge_2358.
# On gene 2555 in seq edge_2358.
# On gene 2556 in seq edge_2358.
# On gene 2557 in seq edge_2358.
# On gene 2558 in seq edge_2358.
# On gene 2559 in seq edge_2358.
# On gene 2560 in seq edge_2358.
# On gene 2561 in seq edge_2358.
# On gene 2562 in seq edge_2358.
# On gene 2563 in seq edge_2358.
# On gene 2564 in seq edge_2358.
# On gene 2565 in seq edge_2358.
# On gene 2566 in seq edge_2358.
# On gene 2567 in seq edge_2358.
