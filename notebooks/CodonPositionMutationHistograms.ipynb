# %% [markdown]
# # Codon position (CP) mutation histograms

# %%
# %run "Header.ipynb"
# %run "LoadMutationJSONData.ipynb"

# %%
# %run "GeneUtils.ipynb"

# %% [markdown]
# ## Values of _p_ (aka _minfreq_) to consider: 2%, 1%, 0.5%, 0.25%, 0.1%, 0.05%, 0%

# %%
percentages = [2, 1, 0.5, 0.25, 0.1, 0.05, 0]

# %% [markdown]
# ### Without normalization (so the y-axis is just # of mutated positions)

# %%
histogram_matrix_maker(percentages, figfilename="unnormalized-cp-hists.png")
# Out:
# CAMP: $p$ = 2% [7, 5, 39, 1]
# BACTERIA: $p$ = 2% [2765, 1842, 10586, 2290]
# BACTEROIDALES: $p$ = 2% [19, 19, 24, 37]
# CAMP: $p$ = 1% [12, 11, 46, 14]
# BACTERIA: $p$ = 1% [3552, 2371, 13396, 2844]
# BACTEROIDALES: $p$ = 1% [72, 61, 86, 90]

# %% [markdown]
# ### With normalization, and making y-axes comparable for each row

# %%
histogram_matrix_maker(percentages, normalize=True, make_yaxes_comparable=True,
                       figfilename="normalized-cp-hists.png")
# Out:
# p=2% mutation at pos 223189 in CAMP for alt = T, ref = G
# p=2% mutation at pos 739708 in CAMP for alt = G, ref = A
# p=2% mutation at pos 766857 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1005013 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1057005 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1056997 in CAMP for alt = T, ref = G
# p=2% mutation at pos 1056919 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1056871 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1056775 in CAMP for alt = G, ref = T
# p=2% mutation at pos 1056703 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1056655 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1056582 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1056556 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1056554 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1056552 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1056394 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1056390 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209001 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209010 in CAMP for alt = C, ref = A
# p=2% mutation at pos 1209022 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209058 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209104 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209115 in CAMP for alt = A, ref = C
# p=2% mutation at pos 1209121 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1209126 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209133 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1209136 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1209142 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1209145 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209148 in CAMP for alt = T, ref = A
# p=2% mutation at pos 1209154 in CAMP for alt = A, ref = T
# p=2% mutation at pos 1209205 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1209241 in CAMP for alt = A, ref = G
# p=2% mutation at pos 1209265 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1209266 in CAMP for alt = G, ref = C
# p=2% mutation at pos 1209297 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1209322 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209325 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209337 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1209400 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1209403 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209418 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209421 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209424 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1209523 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209577 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209610 in CAMP for alt = T, ref = C
# p=2% mutation at pos 1209697 in CAMP for alt = A, ref = T
# p=2% mutation at pos 1209700 in CAMP for alt = C, ref = T
# p=2% mutation at pos 1209757 in CAMP for alt = G, ref = A
# p=2% mutation at pos 1209796 in CAMP for alt = G, ref = A
# p=2% mutation at pos 515385 in CAMP for alt = A, ref = T
# CAMP: $p$ = 2% [1.7609486985331296e-05, 1.2578204989522355e-05, 9.810999891827437e-05, 9.920044441799099e-06]
# BACTERIA: $p$ = 2% [0.004259002823418508, 0.0028372814469211183, 0.016305896523945144, 0.011031997610536762]
# BACTEROIDALES: $p$ = 2% [2.475208829460717e-05, 2.475208829460717e-05, 3.126579574055643e-05, 7.201357747882412e-05]
# CAMP: $p$ = 1% [3.0187691974853652e-05, 2.7672050976949182e-05, 0.00011571948590360566, 0.0001388806221851874]
# BACTERIA: $p$ = 1% [0.005471239793411407, 0.003652114175162851, 0.020634214040692347, 0.013700873888369674]
# BACTEROIDALES: $p$ = 1% [9.379738722166928e-05, 7.946723084058092e-05, 0.0001120357680703272, 0.00017516816143497757]
# CAMP: $p$ = 0.5% [0.0001308133318910325, 0.00013584461388684144, 0.0002867830737611097, 0.0006448028887169415]
# BACTERIA: $p$ = 0.5% [0.00614282215544051, 0.004095728212466478, 0.022451799332422487, 0.0156278603705595]
# BACTEROIDALES: $p$ = 0.5% [0.0005145828882299912, 0.00042599646696508134, 0.0005992610850273316, 0.0008310756103637269]
# CAMP: $p$ = 0.25% [0.00104650665512826, 0.0010238658861471198, 0.0013005863959166116, 0.0037299367101164614]
# BACTERIA: $p$ = 0.25% [0.008373214954105972, 0.006344604929352924, 0.025704968939315755, 0.022097717484511847]
# BACTEROIDALES: $p$ = 0.25% [0.0022433208443849236, 0.0019280574040009798, 0.0025299239720066907, 0.003921820503238665]
# CAMP: $p$ = 0.1% [0.016336572640391636, 0.01582086623582122, 0.018422039027654442, 0.03423407336864869]
# BACTERIA: $p$ = 0.1% [0.04242983427626988, 0.042565383009890434, 0.06360932390448128, 0.07091310254458565]
# BACTEROIDALES: $p$ = 0.1% [0.02257781274914931, 0.021922533780086816, 0.023478007118179496, 0.036503098530144495]
# CAMP: $p$ = 0.05% [0.09267118308080491, 0.09850243891394747, 0.10320920322102674, 0.14577505307223776]
# BACTERIA: $p$ = 0.05% [0.26520725863468536, 0.2720555503355601, 0.2936740330215199, 0.3124849454181079]
# BACTEROIDALES: $p$ = 0.05% [0.10267035950454136, 0.10376466235546083, 0.10446814275962335, 0.1335345820876931]
# CAMP: $p$ = 0% [0.5223074465489179, 0.5445809319443641, 0.54816320472538, 0.5888439180207528]
# BACTERIA: $p$ = 0% [0.26520725863468536, 0.2720555503355601, 0.2936740330215199, 0.3124849454181079]
# BACTEROIDALES: $p$ = 0% [0.4301847808528267, 0.4409636639343835, 0.4282124302381933, 0.46927161185849525]
