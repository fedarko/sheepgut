# %% [markdown]
# # Codon position (CP) mutation histograms

# %%
# %run "Header.ipynb"
# %run "LoadMutationJSONData.ipynb"

# %%
# %run "GeneUtils.ipynb"

# %% [markdown]
# ## Values of _min-freq_ to consider: 2%, 1%, 0.5%, 0.25%, 0.1%, 0.05%, 0%

# %%
percentages = [2, 1, 0.5, 0.25, 0.1, 0.05, 0]

# %% [markdown]
# ### Without normalization (so the y-axis is just # of mutated positions)

# %%
histogram_matrix_maker(percentages, figfilename="unnormalized-cp-hists.png")
# Out:
# CAMP: min-freq = 2% [7, 5, 41, 1]
# BACTERIA: min-freq = 2% [2785, 1855, 10657, 2311]
# BACTEROIDALES: min-freq = 2% [21, 22, 24, 37]
# CAMP: min-freq = 1% [12, 11, 46, 15]
# BACTERIA: min-freq = 1% [3570, 2386, 13443, 2857]
# BACTEROIDALES: min-freq = 1% [79, 68, 93, 103]
# CAMP: min-freq = 0.5% [66, 63, 121, 73]
# BACTERIA: min-freq = 0.5% [4029, 2702, 14659, 3313]
# BACTEROIDALES: min-freq = 0.5% [479, 390, 569, 490]
# CAMP: min-freq = 0.25% [546, 522, 653, 467]
# BACTERIA: min-freq = 0.25% [6144, 4810, 17441, 5002]
# BACTEROIDALES: min-freq = 0.25% [2098, 1848, 2350, 2490]
# CAMP: min-freq = 0.1% [9959, 10185, 11522, 5099]
# BACTERIA: min-freq = 0.1% [38060, 38790, 52587, 18819]
# BACTEROIDALES: min-freq = 0.1% [27100, 26633, 27810, 27141]
# CAMP: min-freq = 0.05% [53615, 57956, 59758, 20180]
# BACTERIA: min-freq = 0.05% [172176, 176622, 190657, 64865]
# BACTEROIDALES: min-freq = 0.05% [111067, 113252, 111355, 92042]
# CAMP: min-freq = 0% [207632, 216482, 217918, 59361]
# BACTERIA: min-freq = 0% [172176, 176622, 190657, 64865]
# BACTEROIDALES: min-freq = 0% [330215, 338489, 328701, 241108]

# %% [markdown]
# ### With normalization, and making y-axes comparable for each row

# %%
histogram_matrix_maker(percentages, normalize=True, make_yaxes_comparable=True,
                       figfilename="normalized-cp-hists.png")
# Out:
# CAMP: min-freq = 2% [1.7609486985331296e-05, 1.2578204989522355e-05, 0.00010314128091408332, 9.920044441799099e-06]
# BACTERIA: min-freq = 2% [0.004289809353786816, 0.002857305691660518, 0.016415259706752637, 0.011133164400851728]
# BACTEROIDALES: min-freq = 2% [2.7357571272986875e-05, 2.8660312762176726e-05, 3.126579574055643e-05, 7.201357747882412e-05]
# CAMP: min-freq = 1% [3.0187691974853652e-05, 2.7672050976949182e-05, 0.00011571948590360566, 0.00014880066662698648]
# BACTERIA: min-freq = 1% [0.005498965670742884, 0.003675219072939082, 0.02070660938705787, 0.013763500949040842]
# BACTEROIDALES: min-freq = 1% [0.00010291657764599824, 8.858642126490987e-05, 0.00012115495849465615, 0.00020047022919780766]
# CAMP: min-freq = 0.5% [0.0001660323058616951, 0.0001584853828679817, 0.000304392560746441, 0.0007241632442513342]
# BACTERIA: min-freq = 0.5% [0.00620597554269554, 0.004161962252758339, 0.022579646433450964, 0.015960265538737247]
# BACTEROIDALES: min-freq = 0.5% [0.0006240131733219387, 0.0005080691807840419, 0.0007412599073490253, 0.0009536933233682113]
# CAMP: min-freq = 0.25% [0.0013735399848558412, 0.0013131646009061338, 0.0016427135716316195, 0.0046326607543201795]
# BACTERIA: min-freq = 0.25% [0.009463766129144057, 0.007408970553577947, 0.026864834807682533, 0.024096965959783792]
# BACTEROIDALES: min-freq = 0.25% [0.0027331516443203077, 0.002407466272022845, 0.00306144249959615, 0.0048463191330343795]
# CAMP: min-freq = 0.1% [0.025053268698130626, 0.025621803563657036, 0.028985215577855314, 0.050582306608733606]
# BACTERIA: min-freq = 0.1% [0.05862482729088912, 0.05974926564933235, 0.08100115062390925, 0.0906598965208259]
# BACTEROIDALES: min-freq = 0.1% [0.03530429435704496, 0.0346959140815933, 0.03622924081436976, 0.05282487855007474]
# CAMP: min-freq = 0.05% [0.13487609210264823, 0.14579648967455153, 0.1503296747527754, 0.20018649683550582]
# BACTERIA: min-freq = 0.05% [0.26520725863468536, 0.2720555503355601, 0.2936740330215199, 0.3124849454181079]
# BACTEROIDALES: min-freq = 0.05% [0.14469158897984918, 0.14753807913372902, 0.14506677852873587, 0.17914253238664674]
# CAMP: min-freq = 0% [0.5223275716769011, 0.5445909945083557, 0.5482034549813465, 0.5888637581096363]
# BACTERIA: min-freq = 0% [0.26520725863468536, 0.2720555503355601, 0.2936740330215199, 0.3124849454181079]
# BACTEROIDALES: min-freq = 0% [0.4301847808528267, 0.4409636639343835, 0.4282124302381933, 0.46927161185849525]
