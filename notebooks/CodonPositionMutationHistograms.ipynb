# %% [markdown]
# # Codon position (CP) mutation histograms

# %%
# %run "Header.ipynb"
# %run "LoadMutationJSONData.ipynb"

# %%
# %run "GeneUtils.ipynb"

# %% [markdown]
# ## Values of _p_ (aka _minfreq_) to consider: 2%, 1%, 0.5%, 0.25%, 0.1%, 0.05%, 0%

# %%
percentages = [2, 1, 0.5, 0.25, 0.1, 0.05, 0]

# %% [markdown]
# ### Without normalization (so the y-axis is just # of mutated positions)

# %%
histogram_matrix_maker(percentages, figfilename="unnormalized-cp-hists.png")
# Out:
# CAMP: $p$ = 2% [7, 5, 39, 1]
# BACTERIA: $p$ = 2% [2860, 1894, 10876, 2346]
# BACTEROIDALES: $p$ = 2% [20, 19, 25, 65]
# CAMP: $p$ = 1% [12, 11, 46, 14]
# BACTERIA: $p$ = 1% [3649, 2436, 13672, 2889]
# BACTEROIDALES: $p$ = 1% [79, 63, 88, 172]
# CAMP: $p$ = 0.5% [52, 54, 113, 64]
# BACTERIA: $p$ = 0.5% [4001, 2677, 14629, 3250]
# BACTEROIDALES: $p$ = 0.5% [402, 327, 461, 508]
# CAMP: $p$ = 0.25% [412, 400, 513, 372]
# BACTERIA: $p$ = 0.25% [5446, 4124, 16721, 4617]
# BACTEROIDALES: $p$ = 0.25% [1730, 1481, 1954, 2108]
# CAMP: $p$ = 0.1% [6380, 6209, 7251, 3406]
# BACTERIA: $p$ = 0.1% [27541, 27683, 41235, 14761]
# BACTEROIDALES: $p$ = 0.1% [17351, 16836, 18085, 19045]
# CAMP: $p$ = 0.05% [36667, 38965, 40893, 14574]
# BACTERIA: $p$ = 0.05% [172319, 176835, 190741, 64974]
# BACTEROIDALES: $p$ = 0.05% [78916, 79741, 80317, 68969]
# CAMP: $p$ = 0% [208456, 217262, 218752, 59648]
# BACTERIA: $p$ = 0% [172319, 176835, 190741, 64974]
# BACTEROIDALES: $p$ = 0% [330413, 338662, 328904, 241499]

# %% [markdown]
# ### With normalization, and making y-axes comparable for each row

# %%
histogram_matrix_maker(percentages, normalize=True, make_yaxes_comparable=True,
                       figfilename="normalized-cp-hists.png")
# Out:
# CAMP: $p$ = 2% [1.7609486985331296e-05, 1.2578204989522355e-05, 9.810999891827437e-05, 9.920044441799099e-06]
# BACTERIA: $p$ = 2% [0.004405333842667968, 0.0029173784258787177, 0.016752591214285604, 0.011301775718043338]
# BACTEROIDALES: $p$ = 2% [2.605482978379702e-05, 2.475208829460717e-05, 3.2568537229746275e-05, 0.00012651033881415046]
# CAMP: $p$ = 1% [3.0187691974853652e-05, 2.7672050976949182e-05, 0.00011571948590360566, 0.0001388806221851874]
# BACTERIA: $p$ = 1% [0.005620651465697698, 0.00375223539885985, 0.02105934415977499, 0.013917659867616028]
# BACTEROIDALES: $p$ = 1% [0.00010291657764599824, 8.207271381896062e-05, 0.0001146412510487069, 0.00033476581963129046]
# CAMP: $p$ = 0.5% [0.0001308133318910325, 0.00013584461388684144, 0.0002842674327632052, 0.0006348828442751423]
# BACTERIA: $p$ = 0.5% [0.0061628464001799105, 0.004123454089797955, 0.022533436637898502, 0.01565676516779235]
# BACTEROIDALES: $p$ = 0.5% [0.0005237020786543202, 0.00042599646696508134, 0.0006005638265165214, 0.0009887269556552068]
# CAMP: $p$ = 0.25% [0.0010364440911366422, 0.0010062563991617883, 0.0012905238319249938, 0.0036902565323492648]
# BACTERIA: $p$ = 0.25% [0.008388618219290125, 0.006352306561945001, 0.025755799714423464, 0.022242241470676084]
# BACTEROIDALES: $p$ = 0.25% [0.0022537427762984426, 0.0019293601454901696, 0.002545556869876969, 0.004102827603388141]
# CAMP: $p$ = 0.1% [0.016049789566630526, 0.015619614955988861, 0.01824091287580532, 0.03378767136876773]
# BACTERIA: $p$ = 0.1% [0.04242213264367781, 0.04264085900929279, 0.06351536398685793, 0.07111061865901011]
# BACTEROIDALES: $p$ = 0.1% [0.022603867578933106, 0.021932955712000334, 0.023560079831998457, 0.03706752927254609]
# CAMP: $p$ = 0.05% [0.09224100847016324, 0.09802195148334772, 0.10287210732730753, 0.14457472769478008]
# BACTERIA: $p$ = 0.05% [0.2654275253268188, 0.2723836398839826, 0.29380342044906677, 0.3130100492345046]
# BACTEROIDALES: $p$ = 0.05% [0.10280714736090629, 0.10388190908948791, 0.10463228818726127, 0.13423525473343298]
# CAMP: $p$ = 0% [0.5244004598591744, 0.5465531944867212, 0.5503014995735989, 0.5917108108644327]
# BACTERIA: $p$ = 0% [0.2654275253268188, 0.2723836398839826, 0.29380342044906677, 0.3130100492345046]
# BACTEROIDALES: $p$ = 0% [0.43044272366768627, 0.4411890382120134, 0.4284768867604988, 0.470032620204285]
